# %%
import pandas as pd

# simulated_data.csv を読み込む
df = pd.read_csv("simulated_data.csv")
df.head()
# Out:
#    x1        x2        x3      time  event  time_true   c1        c2
# 0   1 -0.742192 -0.088614  0.512100      1     0.5121  6.0  5.566095
# 1   0  0.924358 -0.430458  0.704400      1     0.7044  6.0  1.306427
# 2   1  0.034612  0.796544  0.251400      1     0.2514  6.0  1.140207
# 3   1 -0.282796 -0.235834  6.000000      0     8.0001  6.0  6.874488
# 4   0 -0.106182 -0.306697  5.110001      0     8.0001  6.0  5.110001

# %%
df["time"].hist(bins=30)
# Out:
# <Axes: >
