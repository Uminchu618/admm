# %%
import pandas as pd

# simulated_data.csv を読み込む
df = pd.read_csv("simulated_data.csv")
df.head()
# Out:
#     x1        x2        x3        x4        x5      time  event  time_true
# 0  1.0  0.643327  0.760133 -0.520588  0.995701  0.401582      1   0.401582
# 1  0.0 -0.394605  0.229211  0.812601  1.059224  0.226396      1   0.226396
# 2  1.0 -0.005122  0.530065  0.241660  1.025837  1.212332      1   1.212332
# 3  1.0 -0.163443 -0.704673 -1.774962  0.038913  1.649977      1   1.649977
# 4  0.0  0.337575 -0.179611  0.515410 -0.845045  0.102285      1   0.102285

# %%
df["time"].hist(bins=30)
# Out:
# <Axes: >
